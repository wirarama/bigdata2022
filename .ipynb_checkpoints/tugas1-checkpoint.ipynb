# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sqlalchemy import create_engine
from pandas.io import sql

# %%
df = pd.read_csv('vgsales.csv')

# %%
engine = create_engine('sqlite:///:memory:')
df.to_sql('vgsales',engine)
# Out:
# 16598

# %%
nim = 17
awal = nim*10
akhir = awal+200

# %% [markdown]
# buatlah query (Name,Platform,Year,Genre,Publisher,Global_Sales) dengan limit nim(3digit nim kalian)*10 sampai nim*10+200

# %%
res = pd.read_sql_query(
    "SELECT Name,Platform,Year,Genre,Publisher,Global_Sales "+
    "FROM vgsales WHERE Genre='Puzzle'OR Genre='Action' ORDER BY Rank ASC LIMIT ?,?",engine,params=[(awal,akhir)])

# %%
res
# Out:
#                                       Name Platform    Year         Genre  \
# 0                                Dr. Mario       GB  1989.0        Puzzle
# 1                          Pokemon Pinball       GB  1999.0          Misc
# 2                     Assassin's Creed III     X360  2012.0        Action
# 3                         Final Fantasy IX       PS  2000.0  Role-Playing
# 4                        Final Fantasy X-2      PS2  2003.0  Role-Playing
# ..                                     ...      ...     ...           ...
# 365  Professor Layton and the Last Specter       DS  2009.0        Puzzle
# 366                     Monster Hunter Tri      3DS  2011.0  Role-Playing
# 367                                 Jak II      PS2  2003.0      Platform
# 368                   inFAMOUS: Second Son      PS4  2014.0        Action
# 369        Ratchet & Clank: Going Commando      PS2  2003.0      Platform
#
#                        Publisher  Global_Sales
# 0                       Nintendo          5.34
# 1                       Nintendo          5.31
# 2                        Ubisoft          5.30
# 3                     SquareSoft          5.30
# 4                Electronic Arts          5.29
# ..                           ...           ...
# 365                     Nintendo          2.79
# 366                     Nintendo          2.79
# 367  Sony Computer Entertainment          2.78
# 368  Sony Computer Entertainment          2.78
# 369  Sony Computer Entertainment          2.78
#
# [370 rows x 6 columns]

# %%
res=df.iloc[170:370]
# Out:
#      Rank                         Name Platform    Year         Genre  \
# 170   171                    Dr. Mario       GB  1989.0        Puzzle
# 171   172              Pokemon Pinball       GB  1999.0          Misc
# 172   173         Assassin's Creed III     X360  2012.0        Action
# 173   174             Final Fantasy IX       PS  2000.0  Role-Playing
# 174   175            Final Fantasy X-2      PS2  2003.0  Role-Playing
# ..    ...                          ...      ...     ...           ...
# 365   366                Battlefield 4     X360  2013.0       Shooter
# 366   367               FIFA Soccer 11     X360  2010.0        Sports
# 367   368  Rugrats in Paris: The Movie       PS  2000.0        Action
# 368   369       Spyro 2: Ripto's Rage!       PS  1999.0      Platform
# 369   370                  Left 4 Dead     X360  2008.0       Shooter
#
#                        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 170                     Nintendo      2.18      0.96      2.00         0.20
# 171                     Nintendo      3.02      1.12      1.01         0.16
# 172                      Ubisoft      3.13      1.71      0.03         0.44
# 173                   SquareSoft      1.62      0.77      2.78         0.14
# 174              Electronic Arts      1.92      1.08      2.11         0.17
# ..                           ...       ...       ...       ...          ...
# 365              Electronic Arts      2.14      1.08      0.02         0.29
# 366              Electronic Arts      0.71      2.40      0.02         0.40
# 367                          THQ      1.96      1.33      0.00         0.23
# 368  Sony Computer Entertainment      2.14      1.21      0.01         0.17
# 369              Electronic Arts      2.66      0.50      0.05         0.30
#
#      Global_Sales
# 170          5.34
# 171          5.31
# 172          5.30
# 173          5.30
# 174          5.29
# ..            ...
# 365          3.53
# 366          3.53
# 367          3.52
# 368          3.52
# 369          3.52
#
# [200 rows x 11 columns]

# %%
sns.displot(data=res, x="Global_Sales", col="Genre",hue="Platform")
