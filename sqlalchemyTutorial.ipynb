# %%
from sqlalchemy import create_engine
from pandas.io import sql
import pandas as pd

# %%
df = pd.read_csv('vgsales.csv')

# %%
print(df.columns)
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
df['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %%
engine = create_engine('sqlite:///:memory:')
df.to_sql('vgsales',engine)
# Out:
# 16598

# %%
res = pd.read_sql_query("SELECT Name,Platform,Year,Genre,Publisher FROM vgsales",engine)

# %%
res
# Out:
#     index  Rank                        Name Platform    Year         Genre  \
# 0     421   422                    Baseball      NES  1983.0        Sports
# 1     700   702                 Mario Bros.      NES  1983.0      Platform
# 2     763   765                     Mahjong      NES  1983.0          Misc
# 3     298   299                        Golf      NES  1984.0        Sports
# 4     754   756                      Tennis      NES  1984.0        Sports
# ..    ...   ...                         ...      ...     ...           ...
# 95   1451  1453               SaGa Frontier       PS  1997.0  Role-Playing
# 96   1643  1645  Chocobo no Fushigi Dungeon       PS  1997.0  Role-Playing
# 97     52    53                Gran Turismo       PS  1997.0        Racing
# 98   1635  1637            Intelligent Qube       PS  1997.0        Puzzle
# 99   1780  1782     Puyo Puyo Sun Ketteiban       PS  1997.0        Puzzle
#
#                       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                      Nintendo      1.73      0.10      2.35         0.02
# 1                      Nintendo      1.51      0.12      1.63         0.02
# 2                      Nintendo      1.01      0.00      2.13         0.00
# 3                      Nintendo      1.22      0.28      2.46         0.04
# 4                      Nintendo      1.48      0.11      1.56         0.02
# ..                          ...       ...       ...       ...          ...
# 95                   SquareSoft      1.15      0.04      1.07         0.09
# 96                   SquareSoft      1.00      0.00      1.14         0.08
# 97  Sony Computer Entertainment      4.02      3.87      2.54         0.52
# 98  Sony Computer Entertainment      1.13      0.07      1.00         0.02
# 99                      Compile      1.00      0.00      1.07         0.07
#
#     Global_Sales
# 0           3.20
# 1           2.28
# 2           2.14
# 3           4.01
# 4           2.17
# ..           ...
# 95          1.35
# 96          1.22
# 97         10.95
# 98          1.22
# 99          1.15
#
# [100 rows x 12 columns]

# %%
df[['Name','Platform','Year','Genre','Publisher']]
# Out:
#                                                    Name Platform    Year  \
# 0                                            Wii Sports      Wii  2006.0
# 1                                     Super Mario Bros.      NES  1985.0
# 2                                        Mario Kart Wii      Wii  2008.0
# 3                                     Wii Sports Resort      Wii  2009.0
# 4                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16594                     Men in Black II: Alien Escape       GC  2003.0
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16596                                        Know How 2       DS  2010.0
# 16597                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher
# 0            Sports    Nintendo
# 1          Platform    Nintendo
# 2            Racing    Nintendo
# 3            Sports    Nintendo
# 4      Role-Playing    Nintendo
# ...             ...         ...
# 16593      Platform       Kemco
# 16594       Shooter  Infogrames
# 16595        Racing  Activision
# 16596        Puzzle    7G//AMES
# 16597      Platform     Wanadoo
#
# [16598 rows x 5 columns]

# %%
res = pd.read_sql_query("SELECT * FROM vgsales ORDER BY Year,Genre DESC LIMIT 0,100",engine)

# %%
res.describe()
# Out:
#              index          Rank         Year   NA_Sales   EU_Sales  \
# count     49.00000     49.000000    49.000000  49.000000  49.000000
# mean    3951.44898   3953.102041  2005.387755   3.233878   2.049592
# std     5299.72484   5300.279487     5.851696   5.115058   2.640446
# min        1.00000      2.000000  1985.000000   0.000000   0.000000
# 25%       38.00000     39.000000  2002.000000   0.080000   0.040000
# 50%     1032.00000   1034.000000  2006.000000   0.850000   0.640000
# 75%     7264.00000   7266.000000  2008.000000   5.570000   3.580000
# max    16306.00000  16309.000000  2015.000000  29.080000   9.270000
#
#         JP_Sales  Other_Sales  Global_Sales
# count  49.000000    49.000000     49.000000
# mean    1.161224     0.791837      7.236531
# std     2.526329     1.662021      9.853143
# min     0.000000     0.000000      0.010000
# 25%     0.000000     0.020000      0.220000
# 50%     0.000000     0.140000      1.720000
# 75%     0.360000     1.030000     13.100000
# max    10.220000    10.570000     40.240000

# %%
res.to_excel("larisdijepang.xls",index=False)

# %%
sql.execute("UPDATE vgsales SET NA_Sales=NA_Sales+1 WHERE NA_Sales<1",engine)

# %%
sql.execute("DELETE FROM vgsales WHERE JP_Sales<1.0",engine)

# %%
sql.execute("INSERT INTO vgsales (Name,Platform,Year,Genre,Publisher)VALUES(?,?,?,?,?)",engine,params=[('Game Gila','Mobile','2018','Horror','Entahlah'),('Game Horror di SMA','PC','2018','Horror','Indonesia')])

# %%
res = pd.read_sql_query("SELECT Name,Platform,Year,Genre,Publisher FROM vgsales",engine)
print(res)
# Out:
#                                             Name  Platform    Year  \
# 0                                     Wii Sports       Wii  2006.0
# 1                              Super Mario Bros.       NES  1985.0
# 2                                 Mario Kart Wii       Wii  2008.0
# 3                              Wii Sports Resort       Wii  2009.0
# 4                       Pokemon Red/Pokemon Blue  Game Boy  1996.0
# ..                                           ...       ...     ...
# 239                            Derby Stallion 96      SNES  1996.0
# 240    Oshare Majo Love and Berry: DS Collection        DS  2006.0
# 241  Jissen Pachi-Slot Hisshouhou: Hokuto no Ken       PS2  2004.0
# 242                                    Game Gila    Mobile  2018.0
# 243                           Game Horror di SMA        PC  2018.0
#
#             Genre            Publisher
# 0          Sports             Nintendo
# 1        Platform             Nintendo
# 2          Racing             Nintendo
# 3          Sports             Nintendo
# 4    Role-Playing             Nintendo
# ..            ...                  ...
# 239        Sports  ASCII Entertainment
# 240          Misc                 Sega
# 241          Misc    Sammy Corporation
# 242        Horror             Entahlah
# 243        Horror            Indonesia
#
# [244 rows x 5 columns]
