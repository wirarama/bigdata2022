# %%
from sqlalchemy import create_engine
from pandas.io import sql
import pandas as pd

# %%
df = pd.read_csv('vgsales.csv')

# %%
print(df.columns)
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
df['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
engine = create_engine('sqlite:///:memory:')
df.to_sql('vgsales',engine)
# Out:
# 16598

# %%
res = pd.read_sql_query("SELECT Name,Platform,Year,Genre,Publisher FROM vgsales WHERE Name like'%Mario%' OR  Name like'%Luigi%' ORDER BY Global_Sales,Rank ASC",engine)

# %%
res = pd.read_sql_query("SELECT SUM(Global_Sales) as total FROM vgsales WHERE Name like'%Mario%' OR  Name like'%Luigi%'",engine)

# %%
res = pd.read_sql_query("SELECT Genre,SUM(Global_Sales) as total FROM vgsales GROUP BY Genre ORDER BY total DESC",engine)

# %%
res
# Out:
#            Genre    total
# 0         Action  1751.18
# 1         Sports  1330.93
# 2        Shooter  1037.37
# 3   Role-Playing   927.37
# 4       Platform   831.37
# 5           Misc   809.96
# 6         Racing   732.04
# 7       Fighting   448.91
# 8     Simulation   392.20
# 9         Puzzle   244.95
# 10     Adventure   239.04
# 11      Strategy   175.12

# %%
df[['Name','Platform','Year','Genre','Publisher']]
# Out:
#                                                    Name Platform    Year  \
# 0                                            Wii Sports      Wii  2006.0
# 1                                     Super Mario Bros.      NES  1985.0
# 2                                        Mario Kart Wii      Wii  2008.0
# 3                                     Wii Sports Resort      Wii  2009.0
# 4                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16594                     Men in Black II: Alien Escape       GC  2003.0
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16596                                        Know How 2       DS  2010.0
# 16597                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher
# 0            Sports    Nintendo
# ...

# %%
res = pd.read_sql_query("SELECT * FROM vgsales WHERE JP_Sales>2.0 ORDER BY Year,Genre DESC LIMIT 0,100",engine)

# %%
res.describe()
# Out:
#             index        Rank         Year   NA_Sales   EU_Sales   JP_Sales  \
# count   82.000000   82.000000    82.000000  82.000000  82.000000  82.000000
# mean   199.463415  200.536585  2001.243902   4.789512   2.867439   3.399878
# std    224.976882  225.147589     9.153777   6.777103   4.161236   1.398937
# min      0.000000    1.000000  1983.000000   0.000000   0.000000   2.020000
# 25%     27.750000   28.750000  1994.000000   0.282500   0.110000   2.437500
# 50%     83.500000   84.500000  2003.500000   2.695000   1.750000   3.015000
# 75%    331.500000  332.500000  2009.000000   5.965000   3.567500   3.930000
# max    763.000000  765.000000  2015.000000  41.490000  29.020000  10.220000
#
#        Other_Sales  Global_Sales
# count    82.000000     82.000000
# mean      0.686098     11.742561
# std       1.163212     12.098950
# min       0.000000      2.140000
# 25%       0.020000      3.720000
# 50%       0.335000      8.190000
# 75%       0.777500     15.135000
# ...

# %%
res.to_excel("larisdijepang.xlsx",index=False)

# %%
sql.execute("UPDATE vgsales SET NA_Sales=NA_Sales+1 WHERE NA_Sales<1",engine)

# %%
sql.execute("DELETE FROM vgsales WHERE JP_Sales<1.0",engine)

# %%
sql.execute("INSERT INTO vgsales (Name,Platform,Year,Genre,Publisher)VALUES(?,?,?,?,?)",engine,params=[('Game Gila','Mobile','2018','Horror','Entahlah'),('Game Horror di SMA','PC','2018','Horror','Indonesia')])

# %%
res = pd.read_sql_query("SELECT Name,Platform,Year,Genre,Publisher FROM vgsales",engine)
print(res)
# Out:
#                                             Name  Platform    Year  \
# 0                                     Wii Sports       Wii  2006.0
# 1                              Super Mario Bros.       NES  1985.0
# 2                                 Mario Kart Wii       Wii  2008.0
# 3                              Wii Sports Resort       Wii  2009.0
# 4                       Pokemon Red/Pokemon Blue  Game Boy  1996.0
# ..                                           ...       ...     ...
# 239                            Derby Stallion 96      SNES  1996.0
# 240    Oshare Majo Love and Berry: DS Collection        DS  2006.0
# 241  Jissen Pachi-Slot Hisshouhou: Hokuto no Ken       PS2  2004.0
# 242                                    Game Gila    Mobile  2018.0
# 243                           Game Horror di SMA        PC  2018.0
#
#             Genre            Publisher
# 0          Sports             Nintendo
# 1        Platform             Nintendo
# 2          Racing             Nintendo
# ...
